# %%
import requests

# %%
from bs4 import BeautifulSoup
res = requests.get('http://news.sina.com.cn/world/')
res.encoding="utf-8"
sp = BeautifulSoup(res)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\ProgramData\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-9cd04cdd2da8> in <module>()
#       2 res = requests.get('http://news.sina.com.cn/world/')
#       3 res.encoding="utf-8"
# ----> 4 sp = BeautifulSoup(res)
#
# ...

# %%
from bs4 import BeautifulSoup
res = requests.get('http://news.sina.com.cn/world/')
res.encoding="utf-8"
sp = BeautifulSoup(res.text)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\ProgramData\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
news=sp.select(.news-item)
# Out:
#   File "<ipython-input-4-56cb2e72d485>", line 1
#     news=sp.select(.news-item)
#                    ^
# SyntaxError: invalid syntax

# %%
news = sp.select('.news-item')

# %%
print news
# Out:
#   File "<ipython-input-6-072403b45fa2>", line 1
#     print news
#              ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(news)?

# %%
print(news)
# Out:
# [<div class="news-item first-news-item img-news-item">
# <h2><a href="http://news.sina.com.cn/o/2018-06-16/doc-ihcyszsa1480758.shtml" suda-uatrack="key=newsworld_index_2014&amp;value=news_link_1" target="_blank">沙特球员世界杯惨败后遭处罚？沙特足协回应:假的</a></h2>
# <div class="info clearfix info1">
# <div class="time">6月16日 09:05</div>
# <div class="action"><a data-id="gj:comos-hcyszsa1480758:0" href="http://comment5.news.sina.com.cn/comment/skin/default.html?channel=gj&amp;newsid=comos-hcyszsa1480758&amp;style=0" target="_blank">评论</a><span class="spliter">|</span><span class="bdshare_t bds_tools get-codes-bdshare" data="{text:'沙特球员世界杯惨败后遭处罚？沙特足协回应:假的',url:'http://news.sina.com.cn/o/2018-06-16/doc-ihcyszsa1480758.shtml',pic:'http://n.sinaimg.cn/news/transform/116/w550h366/20180616/97VU-hcyszsa1495454.jpg'}" id="bdshare"><span class="bds_more">分享</span></span></div>
# </div>
# </div>, <div class="news-item img-news-item">
# ...

# %%
type(news)
# Out:
# list

# %%
for new in news
# Out:
#   File "<ipython-input-9-47692dc90e9b>", line 1
#     for new in news
#                    ^
# SyntaxError: invalid syntax

# %%
total=[]
for new in news
    title = new.select("h2")
    time = new.select(".time")
    link = new.select("href")
    total.append(title,time,link)
# Out:
#   File "<ipython-input-10-2a27588f98b3>", line 2
#     for new in news
#                    ^
# SyntaxError: invalid syntax

# %%
total=[]
for new in news:
    title = new.select("h2")
    time = new.select(".time")
    link = new.select("href")
    total.append(title,time,link)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-759dc6155e4f> in <module>()
#       4     time = new.select(".time")
#       5     link = new.select("href")
# ----> 6     total.append(title,time,link)
#
# TypeError: append() takes exactly one argument (3 given)

# %%
total=[]
for new in news:
    title = new.select("h2")
    time = new.select(".time")
    link = new.select("href")
    anew=[title,time,link]
    total.append(anew)

# %%
total
# Out:
# [[[<h2><a href="http://news.sina.com.cn/o/2018-06-16/doc-ihcyszsa1480758.shtml" suda-uatrack="key=newsworld_index_2014&amp;value=news_link_1" target="_blank">沙特球员世界杯惨败后遭处罚？沙特足协回应:假的</a></h2>],
#   [<div class="time">6月16日 09:05</div>],
#   []],
#  [[<h2><a href="http://slide.news.sina.com.cn/w/slide_1_2841_286530.html" suda-uatrack="key=newsworld_index_2014&amp;value=news_link_2" target="_blank">万人空巷 埃及市民聚集观战</a></h2>],
#   [<div class="time">6月16日 08:53</div>],
#   []],
#  [[], [], []],
#  [[], [], []],
#  [[<h2><a href="http://news.sina.com.cn/o/2018-06-16/doc-ihcyszsa1403822.shtml" suda-uatrack="key=newsworld_index_2014&amp;value=news_link_4" target="_blank">美启动新边境移民政策 近两千儿童被迫与父母分离</a></h2>],
#   [<div class="time">6月16日 08:42</div>],
#   []],
#  [[<h2><a href="http://news.sina.com.cn/w/2018-06-16/doc-ihcyszsa1259494.shtml" suda-uatrack="key=newsworld_index_2014&amp;value=news_link_5" target="_blank">美媒曝特朗普G7峰会惊人言论 称可让安倍下台</a></h2>],
#   [<div class="time">6月16日 07:53</div>],
# ...

# %%
for new in news:
    title = new.select("h2")
    print title
# Out:
#   File "<ipython-input-14-39af80942081>", line 3
#     print title
#               ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(title)?

# %%
for new in news:
    title = new.select("h2")
    print(title)
# Out:
# [<h2><a href="http://news.sina.com.cn/o/2018-06-16/doc-ihcyszsa1480758.shtml" suda-uatrack="key=newsworld_index_2014&amp;value=news_link_1" target="_blank">沙特球员世界杯惨败后遭处罚？沙特足协回应:假的</a></h2>]
# [<h2><a href="http://slide.news.sina.com.cn/w/slide_1_2841_286530.html" suda-uatrack="key=newsworld_index_2014&amp;value=news_link_2" target="_blank">万人空巷 埃及市民聚集观战</a></h2>]
# []
# []
# [<h2><a href="http://news.sina.com.cn/o/2018-06-16/doc-ihcyszsa1403822.shtml" suda-uatrack="key=newsworld_index_2014&amp;value=news_link_4" target="_blank">美启动新边境移民政策 近两千儿童被迫与父母分离</a></h2>]
# [<h2><a href="http://news.sina.com.cn/w/2018-06-16/doc-ihcyszsa1259494.shtml" suda-uatrack="key=newsworld_index_2014&amp;value=news_link_5" target="_blank">美媒曝特朗普G7峰会惊人言论 称可让安倍下台</a></h2>]
# [<h2><a href="http://news.sina.com.cn/w/2018-06-16/doc-ihcyszsa1048063.shtml" suda-uatrack="key=newsworld_index_2014&amp;value=news_link_6" target="_blank">玻利维亚发生恶性交通事故 已致12人死亡30人受伤</a></h2>]
# []
# ...

# %%
for new in news:
    title = new.select("h2")
    print(title.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-b3eab50e8438> in <module>()
#       1 for new in news:
#       2     title = new.select("h2")
# ----> 3     print(title.text)
#
# AttributeError: 'list' object has no attribute 'text'

# %%
for new in news:
    title = new.select("h2")
    print(title[0].text)
# Out:
# 沙特球员世界杯惨败后遭处罚？沙特足协回应:假的
# 万人空巷 埃及市民聚集观战
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-31b08787f04d> in <module>()
#       1 for new in news:
#       2     title = new.select("h2")
# ----> 3     print(title[0].text)
#       4
#
# IndexError: list index out of range

# %%
for new in news:
    title = new.select("h2")
    if len(title)>0:
        print(title[0].text)
# Out:
# 沙特球员世界杯惨败后遭处罚？沙特足协回应:假的
# 万人空巷 埃及市民聚集观战
# 美启动新边境移民政策 近两千儿童被迫与父母分离
# 美媒曝特朗普G7峰会惊人言论 称可让安倍下台
# 玻利维亚发生恶性交通事故 已致12人死亡30人受伤
# 特朗普竞选团队前竞选经理被令入狱候审
# 美俄再次上演制裁大戏 修复关系尚需时日
# 默克尔：2024年德国防支出将为GDP的1.5%
# 朝鲜半岛有望实现无核化 日本失去拥核唯一借口
# 特朗普团队前竞选主席被判入狱 特朗普：有点糟糕
# 入狱也不忘世界杯 巴西前总统卢拉将任足球评论员
# 中南半岛五国呼吁私营企业助力地区合作发展
# 特朗普：朝鲜已启动归还美军遗骸程序
# 阿富汗官方证实巴基斯坦塔利班头目死于美军空袭
# 芬兰图尔库持刀行凶者被判终身监禁
# 摩洛哥男子在芬兰持刀行凶致2死8伤 被判终身监禁
# 霍金骨灰安葬仪式举行 坟墓纪念碑上刻有黑洞图案
# 印度第4代登陆艇服役：特别“能装” 价格低廉
# 新加坡飞墨尔本航班滑行时折返:因紧急滑梯被启动
# 新西兰拟开征外国游客税 每人35新西兰元
# 越南“反华”游行中 一名美国人被捕
# 阿富汗国防部:巴基斯坦塔利班头目在美空袭中击毙
# 巴西北部帕拉州通报:一监狱发生越狱事件至少23死
# 朴槿惠获刑24年后淡定嘱咐律师：稳住 别冲动
# 法国空军战机误投训练弹 落入工厂内致两伤
# 安理会延长联合国海地司法支助团任期
# 肯尼亚一辆客车翻车坠河造成至少17人死亡
# 英媒：金字塔地理坐标与光速值相同 或外星人所建
# 通俄门调查人悬了？白宫：特朗普当然有权炒他
# 美提议调查化武袭击责任方 俄在联合国投下反对票
# 安理会未通过美俄和禁化武组织的叙化武调查草案
# 英国王子婚礼不请特朗普？皇室称办“私人婚礼”
# 日本爱媛县人士承认为加计学园新学部访首相官邸
# 东南亚忧成美贸易保护主义目标 日媒：泰首当其冲
# 日美印抱团与中国争印太基建 日媒：分工都想好了
# 美媒：中印机场太忙 肯尼迪机场被挤出最繁忙前20
# 特朗普取消拉美之行以应对叙利亚化武问题
# 叙利亚政府邀请禁化武组织进入杜马展开调查
# 俄官员:美国施加制裁致卢布汇率变动不会破坏稳定
# 布基纳法索发生两起袭击1死7伤:一市长被袭击身亡
# 以军公布狙击手射击巴勒斯坦人视频初步调查结果
# ...

# %%
total=[]
for new in news:
    if len(h2)>0:
        title = new.select("h2")[0].text
        time = new.select(".time")[0].text
        link = new.select("href")[0].text
        anew=[title,time,link]
        total.append(anew)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f4168f485f73> in <module>()
#       1 total=[]
#       2 for new in news:
# ----> 3     if len(h2)>0:
#       4         title = new.select("h2")[0].text
#       5         time = new.select(".time")[0].text
#
# NameError: name 'h2' is not defined

# %%
total=[]
for new in news:
        title = new.select("h2")[0].text
        time = new.select(".time")[0].text
        link = new.select("href")[0].text
        if len(h2)>0:
            anew=[title,time,link]
            total.append(anew)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-1b3da3760f3c> in <module>()
#       3         title = new.select("h2")[0].text
#       4         time = new.select(".time")[0].text
# ----> 5         link = new.select("href")[0].text
#       6         if len(h2)>0:
#       7             anew=[title,time,link]
#
# IndexError: list index out of range

# %%
total=[]
for new in news:
     if len(new.select("h2"))>0:
        title = new.select("h2")[0].text
        time = new.select(".time")[0].text
        link = new.select("href")[0].text
        anew=[title,time,link]
        total.append(anew)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-15f6f7befcd7> in <module>()
#       4         title = new.select("h2")[0].text
#       5         time = new.select(".time")[0].text
# ----> 6         link = new.select("href")[0].text
#       7         anew=[title,time,link]
#       8         total.append(anew)
#
# IndexError: list index out of range

# %%
for new in news:
    if len(new.select("h2"))>0:
        link = new.select("href")[0].text
        print link
# Out:
#   File "<ipython-input-22-9946479f8aec>", line 4
#     print link
#              ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(link)?

# %%
for new in news:
    if len(new.select("h2"))>0:
        link = new.select("href")[0].text
        print(link)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-905139cca1e1> in <module>()
#       1 for new in news:
#       2     if len(new.select("h2"))>0:
# ----> 3         link = new.select("href")[0].text
#       4         print(link)
#
# IndexError: list index out of range

# %%
for new in news:
    if len(new.select("h2"))>0:
        link = new.select("a")
        print link
# Out:
#   File "<ipython-input-24-7a62ca4f22dc>", line 4
#     print link
#              ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(link)?

# %%
for new in news:
    if len(new.select("h2"))>0:
        link = new.select("a")
        print(link)
# Out:
# [<a href="http://news.sina.com.cn/o/2018-06-16/doc-ihcyszsa1480758.shtml" suda-uatrack="key=newsworld_index_2014&amp;value=news_link_1" target="_blank">沙特球员世界杯惨败后遭处罚？沙特足协回应:假的</a>, <a data-id="gj:comos-hcyszsa1480758:0" href="http://comment5.news.sina.com.cn/comment/skin/default.html?channel=gj&amp;newsid=comos-hcyszsa1480758&amp;style=0" target="_blank">评论</a>]
# [<a href="http://slide.news.sina.com.cn/w/slide_1_2841_286530.html" suda-uatrack="key=newsworld_index_2014&amp;value=news_link_2" target="_blank">万人空巷 埃及市民聚集观战</a>, <a data-id="gj:slidenews-album-2841-286530:0" href="http://comment5.news.sina.com.cn/comment/skin/default.html?channel=gj&amp;newsid=slidenews-album-2841-286530&amp;style=0" target="_blank">评论</a>]
# ...

# %%
type(link)
# Out:
# list

# %%
link[0]
# Out:
# <a href="http://slide.news.sina.com.cn/w/slide_1_2841_92988.html" target="_blank">组图：巴西真人芭比走红 细腰32F巨胸受追捧</a>

# %%
link[0][href]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-0c999514a86a> in <module>()
# ----> 1 link[0][href]
#
# NameError: name 'href' is not defined

# %%
link[0]['href']
# Out:
# 'http://slide.news.sina.com.cn/w/slide_1_2841_92988.html'

# %%
type(link[0])
# Out:
# bs4.element.Tag

# %%
link[0]
# Out:
# <a href="http://slide.news.sina.com.cn/w/slide_1_2841_92988.html" target="_blank">组图：巴西真人芭比走红 细腰32F巨胸受追捧</a>

# %%
link[0]['target']
# Out:
# '_blank'

# %%
time
# Out:
# '6月16日 09:05'

# %%
total=[]
for new in news:
     if len(new.select("h2"))>0:
        title = new.select("h2")[0].text
        time = new.select(".time")[0].text
        link = new.select("a")[0]["href"]
        anew=[title,time,link]
        total.append(anew)

# %%
total
# Out:
# [['沙特球员世界杯惨败后遭处罚？沙特足协回应:假的',
#   '6月16日 09:05',
#   'http://news.sina.com.cn/o/2018-06-16/doc-ihcyszsa1480758.shtml'],
#  ['万人空巷 埃及市民聚集观战',
#   '6月16日 08:53',
#   'http://slide.news.sina.com.cn/w/slide_1_2841_286530.html'],
#  ['美启动新边境移民政策 近两千儿童被迫与父母分离',
#   '6月16日 08:42',
#   'http://news.sina.com.cn/o/2018-06-16/doc-ihcyszsa1403822.shtml'],
#  ['美媒曝特朗普G7峰会惊人言论 称可让安倍下台',
#   '6月16日 07:53',
#   'http://news.sina.com.cn/w/2018-06-16/doc-ihcyszsa1259494.shtml'],
#  ['玻利维亚发生恶性交通事故 已致12人死亡30人受伤',
#   '6月16日 06:53',
#   'http://news.sina.com.cn/w/2018-06-16/doc-ihcyszsa1048063.shtml'],
#  ['特朗普竞选团队前竞选经理被令入狱候审',
#   '6月16日 04:57',
#   'http://news.sina.com.cn/w/2018-06-16/doc-ihcyszsa0876939.shtml'],
#  ['美俄再次上演制裁大戏 修复关系尚需时日',
#   '6月16日 04:25',
#   'http://news.sina.com.cn/w/2018-06-16/doc-ihcyszsa0870773.shtml'],
#  ['默克尔：2024年德国防支出将为GDP的1.5%',
#   '6月16日 04:25',
#   'http://news.sina.com.cn/w/2018-06-16/doc-ihcyszsa0844896.shtml'],
#  ['朝鲜半岛有望实现无核化 日本失去拥核唯一借口',
#   '6月16日 04:23',
# ...

# %%
 new.select(".time")
# Out:
# [<div class="time">12月18日 15:16</div>]

# %%
new.select("a")
# Out:
# [<a href="http://slide.news.sina.com.cn/w/slide_1_2841_92988.html" target="_blank">组图：巴西真人芭比走红 细腰32F巨胸受追捧</a>,
#  <a data-id="gj:slidenews-album-2841-92988:1" href="http://comment5.news.sina.com.cn/comment/skin/default.html?channel=gj&amp;newsid=slidenews-album-2841-92988&amp;style=1" target="_blank">评论</a>]

# %%
new.select("a")[0].text
# Out:
# '组图：巴西真人芭比走红 细腰32F巨胸受追捧'

# %%
res=requests.get("http://comment5.news.sina.com.cn/page/info?version=1&format=json&channel=gj&newsid=comos-hcyszrz8137443&group=undefined&compress=0&ie=utf-8&oe=utf-8&page=1&page_size=3&t_size=3&h_size=3&thread=1&callback=jsonp_1529118023915&_=1529118023915")
print(res)
# Out:
# <Response [200]>

# %% [raw]
# res

# %%
res.text
res.encoding="utf-8"

# %%
res.text
# Out:
# 'jsonp_1529118023915({"result": {"status": {"msg": "", "code": 0}, "count": {"qreply": 157, "total": 170, "show": 10}, "language": "ch", "encoding": "utf-8", "cmntlist": [{"comment_imgs": "", "parent_mid": "0", "news_mid_source": "0", "rank": "3", "mid": "5B2479F1-DDD89996-49CECCC7-8D6-856", "video": "", "vote": "0", "uid": "1238289607", "area": "\\u5317\\u4eac", "channel_source": "", "content": "\\u7535\\u5f71\\u300a\\u5929\\u7a7a\\u4e4b\\u773c\\u300b\\u7684\\u73b0\\u5b9e\\u7248\\uff01\\uff01\\uff01\\u4e16\\u754c\\u535a\\u5f08\\u9760\\u5634\\u662f\\u6ca1\\u7528\\u7684\\uff01\\u4e5f\\u5f97\\u9760\\u5b9e\\u529b\\uff01\\uff01", "nick": "zhangkw1285", "hot": "0", "status_uid": "0", "content_ext": "", "ip": "221.216.153.150", "media_type": "0", "config": "wb_verified=0&wb_screen_name=zhangkw1285&area=\\u5317\\u4eac&wb_user_id=1238289607&followers_count=3&client_port=0&wb_profile_img=http%3A%2F%2Ftvax4.sinaimg.cn%2Fdefault%2Fimages%2Fdefault_avatar_male_50.gif&wb_time=1529117169", "channe
# ...

# %%
import json
jd = json.loads(res.text.strip(r'jsonp_1529118023915(')
# Out:
#   File "<ipython-input-44-2186b5bdd001>", line 2
#     jd = json.loads(res.text.strip(r'jsonp_1529118023915(')
#                                                            ^
# SyntaxError: unexpected EOF while parsing

# %%
import json
jd = json.loads(res.text.strip('jsonp_1529118023915\(')
# Out:
#   File "<ipython-input-45-8309e10547ed>", line 2
#     jd = json.loads(res.text.strip('jsonp_1529118023915\(')
#                                                            ^
# SyntaxError: unexpected EOF while parsing

# %%
import json
jd = json.loads(res.text.strip('jsonp_1529118023915\('))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-46-712484ed6436> in <module>()
#       1 import json
# ----> 2 jd = json.loads(res.text.strip('jsonp_1529118023915\('))
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     340         end = _w(s, end).end()
#     341         if end != len(s):
# --> 342             raise JSONDecodeError("Extra data", s, end)
#     343         return obj
#     344
#
# ...

# %%
import json
jd = json.loads(res.text.lstrip('jsonp_1529118023915\(').rstrip("\)"))

# %%
jd
# Out:
# {'result': {'status': {'msg': '', 'code': 0},
#   'count': {'qreply': 157, 'total': 170, 'show': 10},
#   'language': 'ch',
#   'encoding': 'utf-8',
#   'cmntlist': [{'comment_imgs': '',
#     'parent_mid': '0',
#     'news_mid_source': '0',
#     'rank': '3',
#     'mid': '5B2479F1-DDD89996-49CECCC7-8D6-856',
#     'video': '',
#     'vote': '0',
#     'uid': '1238289607',
#     'area': '北京',
#     'channel_source': '',
#     'content': '电影《天空之眼》的现实版！！！世界博弈靠嘴是没用的！也得靠实力！！',
#     'nick': 'zhangkw1285',
#     'hot': '0',
#     'status_uid': '0',
#     'content_ext': '',
#     'ip': '221.216.153.150',
#     'media_type': '0',
#     'config': 'wb_verified=0&wb_screen_name=zhangkw1285&area=北京&wb_user_id=1238289607&followers_count=3&client_port=0&wb_profile_img=http%3A%2F%2Ftvax4.sinaimg.cn%2Fdefault%2Fimages%2Fdefault_avatar_male_50.gif&wb_time=1529117169',
#     'channel': 'gj',
#     'comment_mid': '0',
#     'status': 'M_PASWAIT',
#     'openid': '',
#     'newsid_source': '',
# ...

# %%
type(jd)
# Out:
# dict

# %%
print jd
# Out:
#   File "<ipython-input-50-1811da10e6b8>", line 1
#     print jd
#            ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(jd)?

# %%
print(jd)
# Out:
# {'result': {'status': {'msg': '', 'code': 0}, 'count': {'qreply': 157, 'total': 170, 'show': 10}, 'language': 'ch', 'encoding': 'utf-8', 'cmntlist': [{'comment_imgs': '', 'parent_mid': '0', 'news_mid_source': '0', 'rank': '3', 'mid': '5B2479F1-DDD89996-49CECCC7-8D6-856', 'video': '', 'vote': '0', 'uid': '1238289607', 'area': '北京', 'channel_source': '', 'content': '电影《天空之眼》的现实版！！！世界博弈靠嘴是没用的！也得靠实力！！', 'nick': 'zhangkw1285', 'hot': '0', 'status_uid': '0', 'content_ext': '', 'ip': '221.216.153.150', 'media_type': '0', 'config': 'wb_verified=0&wb_screen_name=zhangkw1285&area=北京&wb_user_id=1238289607&followers_count=3&client_port=0&wb_profile_img=http%3A%2F%2Ftvax4.sinaimg.cn%2Fdefault%2Fimages%2Fdefault_avatar_male_50.gif&wb_time=1529117169', 'channel': 'gj', 'comment_mid': '0', 'status': 'M_PASWAIT', 'openid': '', 'newsid_source': '', 'parent': '', 'status_cmnt_mid': '', 'parent_profile_img': '', 'news_mid': '0', 'parent_nick': '', 'newsid': 'comos-hcyszrz8137443', 'parent_uid': '0', 'th
# ...

# %%
print(jd['result']['count']['total'])
# Out:
# 170
